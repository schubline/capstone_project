# %% [markdown]
# # Recommender on Pennsylvania Food Reviewers

# %% [markdown]
# The goal of this notebook is to build a rudimentary recomender system for South Carolina Reviewers

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from scipy import sparse
from sklearn.metrics.pairwise import pairwise_distances, cosine_similarity
# %matplotlib inline 
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
data = pd.read_csv("/home/schubert/DSI/capstone_project/data/food_reviews_pa")

# %%
data.shape
# Out:
# (158521, 21)

# %%
data.head()
# Out:
#               business_id               review_id                 user_id  \
# 0  --GM_ORV2cYS-h38DSaCLw  q6zDnAyfyzEhpFZYU8huPA  2Z8czZ9VpUAy3bd1tRz3HA
# 1  --GM_ORV2cYS-h38DSaCLw  fHr9YK4-LDyD2kGduRjmrw  KUFOLW5C83qpr5zWoIIThQ
# 2  --GM_ORV2cYS-h38DSaCLw  Z2vhgOHG7N0R_fuahMd2AQ  jRiHm_X0on2Zex22Ke6xOg
# 3  --GM_ORV2cYS-h38DSaCLw  grm_MOzOKIw-icfJXv0-KQ  ZjHDoLXzLcj023N1a7WTww
# 4  --GM_ORV2cYS-h38DSaCLw  YGEBymy_9OgZ7_a7Ee0NEA  WZVeGwzAEhcnVAZ5ub8j6w
#
#    stars        date                                               text  \
# 0      4  2016-01-16  Very good quality pizzas. The prices are great...
# 1      1  2015-01-31  They told me they were delivering me pizza, th...
# 2      5  2016-12-13  I eat here quite often,  the high quality food...
# 3      4  2017-01-16  Ordered several pizzas for a work party..chees...
# 4      5  2013-04-13  We have had  many take-out pizzas from here, a...
#
#    useful  funny  cool           name    ...                 address  \
# 0       1      1     1  "Mm Mm Pizza"    ...     "407 S Central Ave"
# 1       0      0     0  "Mm Mm Pizza"    ...     "407 S Central Ave"
# 2       0      0     0  "Mm Mm Pizza"    ...     "407 S Central Ave"
# 3       0      0     1  "Mm Mm Pizza"    ...     "407 S Central Ave"
# 4       1      0     0  "Mm Mm Pizza"    ...     "407 S Central Ave"
#
#          city state postal_code   latitude  longitude  review_count  is_open  \
# 0  Canonsburg    PA     15317.0  40.252569 -80.183859           7.0      1.0
# 1  Canonsburg    PA     15317.0  40.252569 -80.183859           7.0      1.0
# 2  Canonsburg    PA     15317.0  40.252569 -80.183859           7.0      1.0
# 3  Canonsburg    PA     15317.0  40.252569 -80.183859           7.0      1.0
# 4  Canonsburg    PA     15317.0  40.252569 -80.183859           7.0      1.0
#
#                               categories avg_stars
# 0  Pizza;Chicken Wings;Salad;Restaurants       4.0
# 1  Pizza;Chicken Wings;Salad;Restaurants       4.0
# 2  Pizza;Chicken Wings;Salad;Restaurants       4.0
# 3  Pizza;Chicken Wings;Salad;Restaurants       4.0
# 4  Pizza;Chicken Wings;Salad;Restaurants       4.0
#
# [5 rows x 21 columns]

# %%
# let's drop uncecessary columns 
to_drop = ["date", "text", "neighborhood", "address",
           "state", "postal_code", "latitude", "longitude",
           "review_count", "avg_stars"]

data.drop(to_drop, axis=1, inplace=True)

# %%
data.head()
# Out:
#               business_id               review_id                 user_id  \
# 0  --GM_ORV2cYS-h38DSaCLw  q6zDnAyfyzEhpFZYU8huPA  2Z8czZ9VpUAy3bd1tRz3HA
# 1  --GM_ORV2cYS-h38DSaCLw  fHr9YK4-LDyD2kGduRjmrw  KUFOLW5C83qpr5zWoIIThQ
# 2  --GM_ORV2cYS-h38DSaCLw  Z2vhgOHG7N0R_fuahMd2AQ  jRiHm_X0on2Zex22Ke6xOg
# 3  --GM_ORV2cYS-h38DSaCLw  grm_MOzOKIw-icfJXv0-KQ  ZjHDoLXzLcj023N1a7WTww
# 4  --GM_ORV2cYS-h38DSaCLw  YGEBymy_9OgZ7_a7Ee0NEA  WZVeGwzAEhcnVAZ5ub8j6w
#
#    stars  useful  funny  cool           name        city  is_open  \
# 0      4       1      1     1  "Mm Mm Pizza"  Canonsburg      1.0
# 1      1       0      0     0  "Mm Mm Pizza"  Canonsburg      1.0
# 2      5       0      0     0  "Mm Mm Pizza"  Canonsburg      1.0
# 3      4       0      0     1  "Mm Mm Pizza"  Canonsburg      1.0
# 4      5       1      0     0  "Mm Mm Pizza"  Canonsburg      1.0
#
#                               categories
# 0  Pizza;Chicken Wings;Salad;Restaurants
# 1  Pizza;Chicken Wings;Salad;Restaurants
# 2  Pizza;Chicken Wings;Salad;Restaurants
# 3  Pizza;Chicken Wings;Salad;Restaurants
# 4  Pizza;Chicken Wings;Salad;Restaurants

# %%
data["is_open"].value_counts()
# Out:
# 1.0    5497
# 0.0    1311
# Name: is_open, dtype: int64

# %%
# let's drop places that are no longer open. No point in recommending a place that is now closed 
data.drop(data[data.is_open == 0.0].index, inplace=True)

# %%
data["is_open"].value_counts()
# Out:
# 1.0    138290
# Name: is_open, dtype: int64

# %%
# making pure raitings dataframe 
ratings = data[["business_id", "name", "user_id", "stars"]]

# %%
ratings.head()
# Out:
#               business_id           name                 user_id  stars
# 0  --GM_ORV2cYS-h38DSaCLw  "Mm Mm Pizza"  2Z8czZ9VpUAy3bd1tRz3HA      4
# 1  --GM_ORV2cYS-h38DSaCLw  "Mm Mm Pizza"  KUFOLW5C83qpr5zWoIIThQ      1
# 2  --GM_ORV2cYS-h38DSaCLw  "Mm Mm Pizza"  jRiHm_X0on2Zex22Ke6xOg      5
# 3  --GM_ORV2cYS-h38DSaCLw  "Mm Mm Pizza"  ZjHDoLXzLcj023N1a7WTww      4
# 4  --GM_ORV2cYS-h38DSaCLw  "Mm Mm Pizza"  WZVeGwzAEhcnVAZ5ub8j6w      5

# %%
# ratings.to_csv("star_rec_data_pa", encoding='utf-8', index=False)

# %%
ratings["name"].unique()
# Out:
# array(['"Small Bar Fort Mill"', '"Hickory Tavern"',
#        '"Drunken Goat Bar & Grill"',
#        '"Zaxby\'s Chicken Fingers & Buffalo Wings"',
#        '"Hwy 55 Burgers Shakes & Fries"', '"Red Bowl"', '"Local Dish"',
#        '"Groucho\'s Deli"', '"Showmars Fort Mill-Hwy 521"',
#        '"McDonald\'s"', '"Lee\'s Hoagie House"',
#        '"Cracker Barrel Old Country Store"', '"Subway"',
#        '"Bojangles Restaurant"', '"Tian Tian Asian Restaurant"',
#        '"Cajun Yard Dog"', '"Arby\'s"', '"Mamas Pizza & Pasta"',
#        '"Wing King Cafe"', '"Waffle House"', '"521 BBQ & Grill"',
#        '"Toppers Pizza"', '"Golden China"',
#        '"Bojangles\' Famous Chicken \'n Biscuits"', '"Big Wok"',
#        '"Brixx Wood Fired Pizza"', '"Wendy\'s"',
#        '"Danny\'s Pizza and Pasta"', '"Hanako"', '"China II"',
#        '"Famous Toastery"', '"Bagel Boat"',
#        '"Danny\'s Pizza and Pasta Fort Mill"', '"The Roasting Oven"',
#        '"Sub Station II"', '"Carolina Ale House"', '"Papa John\'s Pizza"',
#        '"Tacos Nayarit #2"', '"Hardee\'s of Fort Mill"', '"Taco Bell"',
#        '"Burger King"', '"Chick-fil-A"', '"Mr Pollo"',
#        '"Q2U BBQ Pit and Catering"', '"Domino\'s Pizza"',
#        '"Cherry Sushi & Grill"', '"Culver\'s"',
#        '"Akahana - Asian Bistro, Bar & Sushi"', '"Taqueria La Unica"',
#        '"Empire Pizza & Bar"', '"Six Pence Pub"',
#        '"Sweetwater Sports Bar & Grill"', '"MorningStar Missions Cafe"',
#        '"Peking Tokyo"', '"Rizzo\'s Spaghetti House"', '"Papa Murphy\'s"',
#        '"Marco\'s Pizza"', '"Jersey Mike\'s Subs"', '"The Shore Club"',
#        '"Lee Cafe"', '"Bojangles"', '"Sal\'s Roadside Eatery"',
#        '"Salsarita\'s Fresh Mexican Grill"', '"Archie Boy\'s BBQ"',
#        '"Moe\'s Southwest Grill"', '"Figaro\'s Pizza"',
#        '"Pasquale\'s Restaurant & Pub"', '"KFC"', '"QuikTrip"',
#        '"Towne Tavern"', '"Panda Hut"', '"Tega Cay Gourmet Deli"',
#        '"Los Aztecas"', '"Sweet Dough"', '"Midtown Sundries Grill & Bar"',
#        '"Cruzin Reubenz by Phil\'s Deli"', '"McAlister\'s Deli"',
#        '"Cherry"', '"T-Bones On the Lake"', '"China Inn"', '"China East"',
#        '"Taqueria El Manhattan"', '"Asian Roll & Grill"',
#        '"Pelican\'s SnoBalls"', '"Brew\'s Tavern"',
#        '"Baxter Social House"', '"Dairy Queen"',
#        '"Saiki Japanese Restaurant"', '"Little Caesars Pizza"',
#        '"Charanda Mexican Grill & Cantina"', '"Sabor Latin Street Grill"',
#        '"Fort Mill BBQ Company"', '"Pizza Hut"', '"John\'s Place"',
#        '"Jim \'N Nick\'s Bar-B-Q"',
#        '"Southern Salads & Sandwich Company"', '"Chinatown"',
#        '"Tropical Smoothie Cafe"', '"Blacow Burger"', '"City Tavern"',
#        '"Captain Steve\'s"', '"Fort Mill Family Restaurant"',
#        '"Mulligans Sports Bar & Grille"', '"Carmellas Pizza Grill"',
#        '"Hardee\'s Red Burrito"', '"Fratelli Ristorante & Pizzeria"',
#        '"Village Pizza"', '"The Flipside Cafe"', '"Fish Market"',
#        '"Jimmy John\'s"', '"Panera Bread"', '"Ladles"',
#        '"Greco Fresh Grille"', '"Smoothie King"',
#        '"The Shore Club at Tega Cay"', '"Hobo\'s"'], dtype=object)

# %% [markdown]
# ## Creating a Pivot Table

# %%
# need an index of all users, and single column for every restaurant 
pivot = pd.pivot_table(ratings, index='user_id', columns='name', values='stars')

# %%
pivot.head()
# Out:
# name                    "521 BBQ & Grill"  \
# user_id
# --44NNdtngXMzsxyN7ju6Q                NaN
# --RNUEvgFSw-b-hhhgZzSg                NaN
# -0b84SUGVN0YkG5j2MCmBw                NaN
# -1FEXqwQSerk4L7Vrdodgg                NaN
# -29I2dtVmCaHZNCvUnCZGg                NaN
#
# name                    "Akahana - Asian Bistro, Bar & Sushi"  "Arby's"  \
# user_id
# --44NNdtngXMzsxyN7ju6Q                                    NaN       NaN
# --RNUEvgFSw-b-hhhgZzSg                                    NaN       NaN
# -0b84SUGVN0YkG5j2MCmBw                                    NaN       NaN
# -1FEXqwQSerk4L7Vrdodgg                                    NaN       NaN
# -29I2dtVmCaHZNCvUnCZGg                                    NaN       NaN
#
# name                    "Archie Boy's BBQ"  "Asian Roll & Grill"  \
# user_id
# --44NNdtngXMzsxyN7ju6Q                 NaN                   NaN
# --RNUEvgFSw-b-hhhgZzSg                 NaN                   NaN
# -0b84SUGVN0YkG5j2MCmBw                 NaN                   NaN
# -1FEXqwQSerk4L7Vrdodgg                 NaN                   NaN
# -29I2dtVmCaHZNCvUnCZGg                 NaN                   NaN
#
# name                    "Bagel Boat"  "Baxter Social House"  "Big Wok"  \
# user_id
# --44NNdtngXMzsxyN7ju6Q           NaN                    NaN        NaN
# --RNUEvgFSw-b-hhhgZzSg           NaN                    NaN        1.0
# -0b84SUGVN0YkG5j2MCmBw           NaN                    NaN        NaN
# -1FEXqwQSerk4L7Vrdodgg           NaN                    NaN        NaN
# -29I2dtVmCaHZNCvUnCZGg           NaN                    NaN        NaN
#
# name                    "Blacow Burger"  "Bojangles Restaurant"  \
# user_id
# --44NNdtngXMzsxyN7ju6Q              NaN                     NaN
# --RNUEvgFSw-b-hhhgZzSg              NaN                     NaN
# -0b84SUGVN0YkG5j2MCmBw              NaN                     NaN
# -1FEXqwQSerk4L7Vrdodgg              NaN                     NaN
# -29I2dtVmCaHZNCvUnCZGg              NaN                     NaN
#
# name                                      ...                      \
# user_id                                   ...
# --44NNdtngXMzsxyN7ju6Q                    ...
# --RNUEvgFSw-b-hhhgZzSg                    ...
# -0b84SUGVN0YkG5j2MCmBw                    ...
# -1FEXqwQSerk4L7Vrdodgg                    ...
# -29I2dtVmCaHZNCvUnCZGg                    ...
#
# name                    "The Shore Club"  "Tian Tian Asian Restaurant"  \
# user_id
# --44NNdtngXMzsxyN7ju6Q               NaN                           NaN
# --RNUEvgFSw-b-hhhgZzSg               NaN                           NaN
# -0b84SUGVN0YkG5j2MCmBw               NaN                           NaN
# -1FEXqwQSerk4L7Vrdodgg               NaN                           NaN
# -29I2dtVmCaHZNCvUnCZGg               NaN                           NaN
#
# name                    "Toppers Pizza"  "Towne Tavern"  \
# user_id
# --44NNdtngXMzsxyN7ju6Q              NaN             NaN
# --RNUEvgFSw-b-hhhgZzSg              NaN             NaN
# -0b84SUGVN0YkG5j2MCmBw              NaN             NaN
# -1FEXqwQSerk4L7Vrdodgg              NaN             NaN
# -29I2dtVmCaHZNCvUnCZGg              NaN             NaN
#
# name                    "Tropical Smoothie Cafe"  "Village Pizza"  \
# user_id
# --44NNdtngXMzsxyN7ju6Q                       NaN              NaN
# --RNUEvgFSw-b-hhhgZzSg                       NaN              NaN
# -0b84SUGVN0YkG5j2MCmBw                       NaN              NaN
# -1FEXqwQSerk4L7Vrdodgg                       NaN              NaN
# -29I2dtVmCaHZNCvUnCZGg                       NaN              NaN
#
# name                    "Waffle House"  "Wendy's"  "Wing King Cafe"  \
# user_id
# --44NNdtngXMzsxyN7ju6Q             NaN        NaN               NaN
# --RNUEvgFSw-b-hhhgZzSg             NaN        NaN               NaN
# -0b84SUGVN0YkG5j2MCmBw             NaN        NaN               NaN
# -1FEXqwQSerk4L7Vrdodgg             NaN        NaN               NaN
# -29I2dtVmCaHZNCvUnCZGg             NaN        NaN               5.0
#
# name                    "Zaxby's Chicken Fingers & Buffalo Wings"
# user_id
# --44NNdtngXMzsxyN7ju6Q                                        NaN
# --RNUEvgFSw-b-hhhgZzSg                                        NaN
# -0b84SUGVN0YkG5j2MCmBw                                        NaN
# -1FEXqwQSerk4L7Vrdodgg                                        NaN
# -29I2dtVmCaHZNCvUnCZGg                                        NaN
#
# [5 rows x 116 columns]

# %%
pivot.shape
# Out:
# (3361, 116)

# %% [markdown]
# ### Making Sparse matrix from Pivot (Item-Based Collaborative Filter

# %%
# item based colaborative filter, so we transpose, and create a sparse dataframe 
sparse_pivot = sparse.csr_matrix(pivot.T.fillna(0))

# %%
print(sparse_pivot)
# Out:
#   (0, 26)	3.0
#   (0, 43)	4.0
#   (0, 48)	5.0
#   (0, 55)	3.0
#   (0, 71)	5.0
#   (0, 80)	4.0
#   (0, 112)	5.0
#   (0, 117)	4.0
#   (0, 155)	4.0
#   (0, 177)	5.0
#   (0, 187)	3.0
#   (0, 198)	4.0
#   (0, 207)	5.0
#   (0, 251)	2.0
#   (0, 263)	4.0
#   (0, 265)	3.0
#   (0, 269)	4.0
#   (0, 281)	5.0
#   (0, 287)	2.0
#   (0, 292)	5.0
#   (0, 299)	4.0
#   (0, 305)	5.0
#   (0, 307)	4.0
#   (0, 320)	4.0
#   (0, 347)	4.0
#   :	:
#   (115, 1169)	3.0
#   (115, 1399)	1.0
#   (115, 1521)	2.5
#   (115, 1556)	2.0
#   (115, 1610)	3.0
#   (115, 1768)	3.0
#   (115, 1886)	1.0
#   (115, 1932)	4.0
#   (115, 2116)	2.0
#   (115, 2357)	1.0
#   (115, 2371)	3.0
#   (115, 2400)	1.0
#   (115, 2415)	1.0
#   (115, 2569)	4.0
#   (115, 2736)	4.0
#   (115, 2743)	1.0
#   (115, 2849)	1.0
#   (115, 2863)	3.0
#   (115, 2869)	2.0
#   (115, 2946)	5.0
#   (115, 2953)	5.0
#   (115, 3124)	4.0
#   (115, 3176)	3.0
#   (115, 3285)	3.0
#   (115, 3357)	5.0

# %% [markdown]
# ### Calculating Cosine Similarity

# %%
sparse_pivot.shape
# Out:
# (116, 3361)

# %%
distances = pairwise_distances(sparse_pivot, metric='cosine')

# %%
distances.shape
# Out:
# (116, 116)

# %%
distance_df = pd.DataFrame(distances, index=pivot.columns, columns=pivot.columns)
distance_df.head()
# Out:
# name                                   "521 BBQ & Grill"  \
# name
# "521 BBQ & Grill"                               0.000000
# "Akahana - Asian Bistro, Bar & Sushi"           0.932733
# "Arby's"                                        1.000000
# "Archie Boy's BBQ"                              1.000000
# "Asian Roll & Grill"                            0.963776
#
# name                                   "Akahana - Asian Bistro, Bar & Sushi"  \
# name
# "521 BBQ & Grill"                                                   0.932733
# "Akahana - Asian Bistro, Bar & Sushi"                               0.000000
# "Arby's"                                                            1.000000
# "Archie Boy's BBQ"                                                  1.000000
# "Asian Roll & Grill"                                                0.934566
#
# name                                   "Arby's"  "Archie Boy's BBQ"  \
# name
# "521 BBQ & Grill"                           1.0                 1.0
# "Akahana - Asian Bistro, Bar & Sushi"       1.0                 1.0
# "Arby's"                                    0.0                 1.0
# "Archie Boy's BBQ"                          1.0                 0.0
# "Asian Roll & Grill"                        1.0                 1.0
#
# name                                   "Asian Roll & Grill"  "Bagel Boat"  \
# name
# "521 BBQ & Grill"                                  0.963776           1.0
# "Akahana - Asian Bistro, Bar & Sushi"              0.934566           1.0
# "Arby's"                                           1.000000           1.0
# "Archie Boy's BBQ"                                 1.000000           1.0
# "Asian Roll & Grill"                               0.000000           1.0
#
# name                                   "Baxter Social House"  "Big Wok"  \
# name
# "521 BBQ & Grill"                                        1.0   1.000000
# "Akahana - Asian Bistro, Bar & Sushi"                    1.0   0.960653
# "Arby's"                                                 1.0   1.000000
# "Archie Boy's BBQ"                                       1.0   1.000000
# "Asian Roll & Grill"                                     1.0   0.988573
#
# name                                   "Blacow Burger"  \
# name
# "521 BBQ & Grill"                             0.975221
# "Akahana - Asian Bistro, Bar & Sushi"         0.963379
# "Arby's"                                      1.000000
# "Archie Boy's BBQ"                            1.000000
# "Asian Roll & Grill"                          0.996624
#
# name                                   "Bojangles Restaurant"  \
# name
# "521 BBQ & Grill"                                    0.964785
# "Akahana - Asian Bistro, Bar & Sushi"                0.961448
# "Arby's"                                             1.000000
# "Archie Boy's BBQ"                                   1.000000
# "Asian Roll & Grill"                                 1.000000
#
# name                                                     ...                      \
# name                                                     ...
# "521 BBQ & Grill"                                        ...
# "Akahana - Asian Bistro, Bar & Sushi"                    ...
# "Arby's"                                                 ...
# "Archie Boy's BBQ"                                       ...
# "Asian Roll & Grill"                                     ...
#
# name                                   "The Shore Club"  \
# name
# "521 BBQ & Grill"                              0.979344
# "Akahana - Asian Bistro, Bar & Sushi"          0.969849
# "Arby's"                                       1.000000
# "Archie Boy's BBQ"                             1.000000
# "Asian Roll & Grill"                           1.000000
#
# name                                   "Tian Tian Asian Restaurant"  \
# name
# "521 BBQ & Grill"                                          0.926913
# "Akahana - Asian Bistro, Bar & Sushi"                      0.966311
# "Arby's"                                                   1.000000
# "Archie Boy's BBQ"                                         1.000000
# "Asian Roll & Grill"                                       1.000000
#
# name                                   "Toppers Pizza"  "Towne Tavern"  \
# name
# "521 BBQ & Grill"                                  1.0        0.918222
# "Akahana - Asian Bistro, Bar & Sushi"              1.0        0.914840
# "Arby's"                                           1.0        1.000000
# "Archie Boy's BBQ"                                 1.0        1.000000
# "Asian Roll & Grill"                               1.0        0.961951
#
# name                                   "Tropical Smoothie Cafe"  \
# name
# "521 BBQ & Grill"                                      0.947555
# "Akahana - Asian Bistro, Bar & Sushi"                  0.960469
# "Arby's"                                               1.000000
# "Archie Boy's BBQ"                                     1.000000
# "Asian Roll & Grill"                                   0.967199
#
# name                                   "Village Pizza"  "Waffle House"  \
# name
# "521 BBQ & Grill"                             0.994451        0.923165
# "Akahana - Asian Bistro, Bar & Sushi"         0.982687        1.000000
# "Arby's"                                      1.000000        1.000000
# "Archie Boy's BBQ"                            1.000000        1.000000
# "Asian Roll & Grill"                          0.973536        1.000000
#
# name                                   "Wendy's"  "Wing King Cafe"  \
# name
# "521 BBQ & Grill"                       0.979483          0.956870
# "Akahana - Asian Bistro, Bar & Sushi"   0.924690          0.962227
# "Arby's"                                1.000000          1.000000
# "Archie Boy's BBQ"                      1.000000          1.000000
# "Asian Roll & Grill"                    0.930933          0.979431
#
# name                                   "Zaxby's Chicken Fingers & Buffalo Wings"
# name
# "521 BBQ & Grill"                                                       0.956629
# "Akahana - Asian Bistro, Bar & Sushi"                                   0.943023
# "Arby's"                                                                1.000000
# "Archie Boy's BBQ"                                                      1.000000
# "Asian Roll & Grill"                                                    0.972923
#
# [5 rows x 116 columns]

# %%
# buiild recommender on train, holding out other reviews users have rated 5 stars, 
# predict how many stars a user, 5 class output, NN, sigmoid on output, cap at 5 stars, careful
# as does introduce some error. 
# or turn it into a two class problem

# %%
search = '"Arby\'s"'
for resto in ratings.loc[ratings['name'].str.contains(search), 'name'].values:
    print(resto)
    print('Average Rating', pivot[resto].mean())
    print('Count of ratings', pivot[resto].count())
    print('Similar Restaurants')
    print(distance_df[resto].sort_values()[1:11])
    print('')
    print('')
# Out:
# "Arby's"
# Average Rating 1.3333333333333333
# Count of ratings 3
# Similar Restaurants
# name
# "Bojangles"                      0.729631
# "The Flipside Cafe"              0.960277
# "Local Dish"                     0.971977
# "Jim 'N Nick's Bar-B-Q"          0.977320
# "521 BBQ & Grill"                1.000000
# "Papa Murphy's"                  1.000000
# "Pasquale's Restaurant & Pub"    1.000000
# "Peking Tokyo"                   1.000000
# "Pizza Hut"                      1.000000
# "Papa John's Pizza"              1.000000
# Name: "Arby's", dtype: float64
#
#
# "Arby's"
# Average Rating 1.3333333333333333
# Count of ratings 3
# Similar Restaurants
# name
# "Bojangles"                      0.729631
# "The Flipside Cafe"              0.960277
# "Local Dish"                     0.971977
# "Jim 'N Nick's Bar-B-Q"          0.977320
# "521 BBQ & Grill"                1.000000
# "Papa Murphy's"                  1.000000
# "Pasquale's Restaurant & Pub"    1.000000
# "Peking Tokyo"                   1.000000
# "Pizza Hut"                      1.000000
# "Papa John's Pizza"              1.000000
# Name: "Arby's", dtype: float64
#
#
# "Arby's"
# Average Rating 1.3333333333333333
# Count of ratings 3
# Similar Restaurants
# name
# "Bojangles"                      0.729631
# "The Flipside Cafe"              0.960277
# "Local Dish"                     0.971977
# "Jim 'N Nick's Bar-B-Q"          0.977320
# "521 BBQ & Grill"                1.000000
# "Papa Murphy's"                  1.000000
# "Pasquale's Restaurant & Pub"    1.000000
# "Peking Tokyo"                   1.000000
# "Pizza Hut"                      1.000000
# "Papa John's Pizza"              1.000000
# Name: "Arby's", dtype: float64

# %%
# Next is to create similar users recomender system. Script and scale.
