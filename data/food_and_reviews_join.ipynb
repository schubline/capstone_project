# %% [markdown]
# # Joining Food businesses and Reviews

# %% [markdown]
# The goal of this notebook is to join the food businesses and the corresponding reviews. Do not need rest for now

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
reviews = pd.read_csv("~/DSI/capstone_project/data/yelp_review.csv")

# %%
food = pd.read_csv("/home/schubert/DSI/capstone_project/eda_notebooks/business_food")

# %%
food["avg_stars"] = food["stars"]

# %%
food.drop("stars", axis=1, inplace=True)

# %%
food.head()
# Out:
#               business_id                          name        neighborhood  \
# 0  PfOCPjBrlQAnz__NXj9h_w    "Brick House Tavern + Tap"                 NaN
# 1  o9eMRCWt5PkpLDE0gOPtcQ                     "Messina"                 NaN
# 2  XOSRcvtaKc_Q5H1SAzN20A           "East Coast Coffee"                 NaN
# 3  fNMVV_ZX7CJSDWQGdOM8Nw  "Showmars Government Center"              Uptown
# 4  l09JfMeQ6ynYs5MCJtrcmQ              "Alize Catering"  Yonge and Eglinton
#
#               address            city state postal_code   latitude  longitude  \
# 0      "581 Howe Ave"  Cuyahoga Falls    OH       44221  41.119535 -81.475690
# 1    "Richterstr. 11"       Stuttgart    BW       70567  48.727200   9.147950
# 2  "737 West Pike St"         Houston    PA       15342  40.241548 -80.212815
# 3      "600 E 4th St"       Charlotte    NC       28202  35.221647 -80.839345
# 4     "2459 Yonge St"         Toronto    ON     M4P 2H6  43.711399 -79.399339
#
#    review_count  is_open                                         categories  \
# 0           116        1  American (New);Nightlife;Bars;Sandwiches;Ameri...
# 1             5        1                                Italian;Restaurants
# 2             3        0  Breakfast & Brunch;Gluten-Free;Coffee & Tea;Fo...
# 3             7        1                 Restaurants;American (Traditional)
# 4            12        0                         Italian;French;Restaurants
#
#    avg_stars
# 0        3.5
# 1        4.0
# 2        4.5
# 3        3.5
# 4        3.0

# %%
food_reviews = reviews.set_index("business_id").join(food.set_index("business_id"))

# %%
# food_reviews.to_csv('food_reviews', index=False)

# %%
food_reviews.head()
# Out:
#                                      review_id                 user_id  stars  \
# business_id
# --6MefnULPED_I942VcFNA  hTGD7YEb43cFCswkpZ9ORA  FEg8v92qx3kK4Hu4TF28Fg      4
# --6MefnULPED_I942VcFNA  GAaVSO7hu3peq3cFtno1FQ  HPtjvIrhzAUkKsiVkeT4MA      3
# --6MefnULPED_I942VcFNA  mMuhOMTT2tTDrcLtbs3AqA  MpvqV7lQcl15rflTBEUhXA      2
# --6MefnULPED_I942VcFNA  IJGTo-etf2iWnqVjwL0F9g  x-Gbs8sVid3yhJIoHD6Gfw      2
# --6MefnULPED_I942VcFNA  _08Gus_KbB879F7lCDSpdw  7Dykd1HolQx8mKPYhYDYSg      2
#
#                               date  \
# business_id
# --6MefnULPED_I942VcFNA  2017-08-17
# --6MefnULPED_I942VcFNA  2017-05-31
# --6MefnULPED_I942VcFNA  2016-10-23
# --6MefnULPED_I942VcFNA  2017-07-30
# --6MefnULPED_I942VcFNA  2017-02-07
#
#                                                                      text  \
# business_id
# --6MefnULPED_I942VcFNA  This is one of my top 3 places to get BBQ pork...
# --6MefnULPED_I942VcFNA  This restaurant is famous for their BBQ dishes...
# --6MefnULPED_I942VcFNA  Roasted pork is one of my favorite things... A...
# --6MefnULPED_I942VcFNA  I walked by the restaurant more than 5 years a...
# --6MefnULPED_I942VcFNA  I came here to order a roast duck over rice to...
#
#                         useful  funny  cool                             name  \
# business_id
# --6MefnULPED_I942VcFNA       2      0     0  "John's Chinese BBQ Restaurant"
# --6MefnULPED_I942VcFNA       0      0     0  "John's Chinese BBQ Restaurant"
# --6MefnULPED_I942VcFNA       1      0     0  "John's Chinese BBQ Restaurant"
# --6MefnULPED_I942VcFNA       1      0     0  "John's Chinese BBQ Restaurant"
# --6MefnULPED_I942VcFNA       0      1     0  "John's Chinese BBQ Restaurant"
#
#                        neighborhood  \
# business_id
# --6MefnULPED_I942VcFNA          NaN
# --6MefnULPED_I942VcFNA          NaN
# --6MefnULPED_I942VcFNA          NaN
# --6MefnULPED_I942VcFNA          NaN
# --6MefnULPED_I942VcFNA          NaN
#
#                                                              address  \
# business_id
# --6MefnULPED_I942VcFNA  "328 Highway 7 E, Chalmers Gate 11, Unit 10"
# --6MefnULPED_I942VcFNA  "328 Highway 7 E, Chalmers Gate 11, Unit 10"
# --6MefnULPED_I942VcFNA  "328 Highway 7 E, Chalmers Gate 11, Unit 10"
# --6MefnULPED_I942VcFNA  "328 Highway 7 E, Chalmers Gate 11, Unit 10"
# --6MefnULPED_I942VcFNA  "328 Highway 7 E, Chalmers Gate 11, Unit 10"
#
#                                  city state postal_code   latitude  longitude  \
# business_id
# --6MefnULPED_I942VcFNA  Richmond Hill    ON     L4B 3P7  43.840905 -79.399604
# --6MefnULPED_I942VcFNA  Richmond Hill    ON     L4B 3P7  43.840905 -79.399604
# --6MefnULPED_I942VcFNA  Richmond Hill    ON     L4B 3P7  43.840905 -79.399604
# --6MefnULPED_I942VcFNA  Richmond Hill    ON     L4B 3P7  43.840905 -79.399604
# --6MefnULPED_I942VcFNA  Richmond Hill    ON     L4B 3P7  43.840905 -79.399604
#
#                         review_count  is_open           categories  avg_stars
# business_id
# --6MefnULPED_I942VcFNA          37.0      1.0  Chinese;Restaurants        3.0
# --6MefnULPED_I942VcFNA          37.0      1.0  Chinese;Restaurants        3.0
# --6MefnULPED_I942VcFNA          37.0      1.0  Chinese;Restaurants        3.0
# --6MefnULPED_I942VcFNA          37.0      1.0  Chinese;Restaurants        3.0
# --6MefnULPED_I942VcFNA          37.0      1.0  Chinese;Restaurants        3.0

# %%
food_reviews["state"].unique()
# Out:
# array(['ON', nan, 'NV', 'PA', 'OH', 'NC', 'AZ', 'BW', 'IL', 'QC', 'CHE',
#        'EDH', 'WI', 'SC', 'NYK', '01', 'NY', 'ELN', 'MLN', 'C', 'HLD',
#        'NI', 'WLN', 'ST', 'B', 'BY', 'FIF', 'WHT', 'XGL', '3', 'IN', 'VS',
#        'ESX', 'CO', 'CA', 'KHL', 'VA', 'RCC', '6', '30', 'PKN', 'HU',
#        'ZET', 'AK', 'GLG', 'ABE'], dtype=object)

# %%
food_reviews["state"].value_counts()
# Out:
# NV     1041833
# AZ      920356
# ON      458012
# NC      201422
# OH      169961
# PA      158521
# QC      111323
# WI       75039
# BW       25482
# EDH      25250
# IL       24174
# SC        6808
# MLN       1150
# HLD        642
# NYK        345
# CHE        306
# C          146
# ELN        124
# FIF        122
# WLN         93
# NY          79
# NI          70
# GLG         55
# 01          40
# ST          38
# IN          25
# PKN         24
# AK          21
# ESX         11
# BY          10
# VS           9
# RCC          8
# KHL          7
# XGL          6
# B            6
# CO           6
# ZET          4
# WHT          4
# CA           4
# 3            4
# ABE          3
# 30           3
# 6            3
# VA           3
# HU           3
# Name: state, dtype: int64

# %%
sns.set(style="darkgrid")
ax = sns.countplot(x="state", data=food_reviews)

# %%
food_reviews_sc = food_reviews[food_reviews["state"].str.contains("SC", na=False)]

# %%
food_reviews_nv = food_reviews[food_reviews["state"].str.contains("NV", na=False)]

# %%
food_reviews_il = food_reviews[food_reviews["state"].str.contains("IL", na=False)]

# %%
food_reviews_pa = food_reviews[food_reviews["state"].str.contains("PA", na=False)]

# %%
food_reviews_pa.head()
# Out:
#                                      review_id                 user_id  stars  \
# business_id
# --GM_ORV2cYS-h38DSaCLw  q6zDnAyfyzEhpFZYU8huPA  2Z8czZ9VpUAy3bd1tRz3HA      4
# --GM_ORV2cYS-h38DSaCLw  fHr9YK4-LDyD2kGduRjmrw  KUFOLW5C83qpr5zWoIIThQ      1
# --GM_ORV2cYS-h38DSaCLw  Z2vhgOHG7N0R_fuahMd2AQ  jRiHm_X0on2Zex22Ke6xOg      5
# --GM_ORV2cYS-h38DSaCLw  grm_MOzOKIw-icfJXv0-KQ  ZjHDoLXzLcj023N1a7WTww      4
# --GM_ORV2cYS-h38DSaCLw  YGEBymy_9OgZ7_a7Ee0NEA  WZVeGwzAEhcnVAZ5ub8j6w      5
#
#                               date  \
# business_id
# --GM_ORV2cYS-h38DSaCLw  2016-01-16
# --GM_ORV2cYS-h38DSaCLw  2015-01-31
# --GM_ORV2cYS-h38DSaCLw  2016-12-13
# --GM_ORV2cYS-h38DSaCLw  2017-01-16
# --GM_ORV2cYS-h38DSaCLw  2013-04-13
#
#                                                                      text  \
# business_id
# --GM_ORV2cYS-h38DSaCLw  Very good quality pizzas. The prices are great...
# --GM_ORV2cYS-h38DSaCLw  They told me they were delivering me pizza, th...
# --GM_ORV2cYS-h38DSaCLw  I eat here quite often,  the high quality food...
# --GM_ORV2cYS-h38DSaCLw  Ordered several pizzas for a work party..chees...
# --GM_ORV2cYS-h38DSaCLw  We have had  many take-out pizzas from here, a...
#
#                         useful  funny  cool           name neighborhood  \
# business_id
# --GM_ORV2cYS-h38DSaCLw       1      1     1  "Mm Mm Pizza"          NaN
# --GM_ORV2cYS-h38DSaCLw       0      0     0  "Mm Mm Pizza"          NaN
# --GM_ORV2cYS-h38DSaCLw       0      0     0  "Mm Mm Pizza"          NaN
# --GM_ORV2cYS-h38DSaCLw       0      0     1  "Mm Mm Pizza"          NaN
# --GM_ORV2cYS-h38DSaCLw       1      0     0  "Mm Mm Pizza"          NaN
#
#                                     address        city state postal_code  \
# business_id
# --GM_ORV2cYS-h38DSaCLw  "407 S Central Ave"  Canonsburg    PA       15317
# --GM_ORV2cYS-h38DSaCLw  "407 S Central Ave"  Canonsburg    PA       15317
# --GM_ORV2cYS-h38DSaCLw  "407 S Central Ave"  Canonsburg    PA       15317
# --GM_ORV2cYS-h38DSaCLw  "407 S Central Ave"  Canonsburg    PA       15317
# --GM_ORV2cYS-h38DSaCLw  "407 S Central Ave"  Canonsburg    PA       15317
#
#                          latitude  longitude  review_count  is_open  \
# business_id
# --GM_ORV2cYS-h38DSaCLw  40.252569 -80.183859           7.0      1.0
# --GM_ORV2cYS-h38DSaCLw  40.252569 -80.183859           7.0      1.0
# --GM_ORV2cYS-h38DSaCLw  40.252569 -80.183859           7.0      1.0
# --GM_ORV2cYS-h38DSaCLw  40.252569 -80.183859           7.0      1.0
# --GM_ORV2cYS-h38DSaCLw  40.252569 -80.183859           7.0      1.0
#
#                                                    categories  avg_stars
# business_id
# --GM_ORV2cYS-h38DSaCLw  Pizza;Chicken Wings;Salad;Restaurants        4.0
# --GM_ORV2cYS-h38DSaCLw  Pizza;Chicken Wings;Salad;Restaurants        4.0
# --GM_ORV2cYS-h38DSaCLw  Pizza;Chicken Wings;Salad;Restaurants        4.0
# --GM_ORV2cYS-h38DSaCLw  Pizza;Chicken Wings;Salad;Restaurants        4.0
# --GM_ORV2cYS-h38DSaCLw  Pizza;Chicken Wings;Salad;Restaurants        4.0

# %%
# food_reviews_pa.to_csv('food_reviews_pa', index=True)

# %% [markdown]
# Starting with South Carolina!

# %% [markdown]
# Checking QC/ Montreal because I'm homesick

# %%
food_reviews_qc = food_reviews[food_reviews["state"].str.contains("QC", na=False)]

# %%
food_reviews_qc.head()
# Out:
#                                      review_id                 user_id  stars  \
# business_id
# -0uEqc2vw1xXtuI_r1xTNg  1HPuIAPqEhKZUEowjpagHw  cqagyVkvbBB32agnJsIhVA      3
# -0uEqc2vw1xXtuI_r1xTNg  xCW5XHwNhCNG9HpBwQA6PQ  7Yv44diO5hwQb0SYa8TpVg      3
# -0uEqc2vw1xXtuI_r1xTNg  XNlojY41x6TxaPCfRHDIrw  cB4YGv6Yg3IYXAIjwpdl1Q      4
# -0uEqc2vw1xXtuI_r1xTNg  v_OQJjmkcE009GkzDDHmow  -f8BL4gHPtXAI0AjYJ0xyQ      5
# -0uEqc2vw1xXtuI_r1xTNg  0Eh2GEDl4nFTWR6bqvojBw  H0gVSvuL8iUGIAqNfHhl9w      2
#
#                               date  \
# business_id
# -0uEqc2vw1xXtuI_r1xTNg  2012-06-07
# -0uEqc2vw1xXtuI_r1xTNg  2013-08-18
# -0uEqc2vw1xXtuI_r1xTNg  2013-04-20
# -0uEqc2vw1xXtuI_r1xTNg  2012-08-18
# -0uEqc2vw1xXtuI_r1xTNg  2013-04-16
#
#                                                                      text  \
# business_id
# -0uEqc2vw1xXtuI_r1xTNg  A small restaurant near the eastern end of Roy...
# -0uEqc2vw1xXtuI_r1xTNg  Went in May with a Groupon coupon and it was p...
# -0uEqc2vw1xXtuI_r1xTNg  Le Roy pendu, vive le Roy! Petit restaurant de...
# -0uEqc2vw1xXtuI_r1xTNg  I had brunch here the other day, it was great!...
# -0uEqc2vw1xXtuI_r1xTNg  Me and a friend ended up here for brunch after...
#
#                         useful  funny  cool            name  \
# business_id
# -0uEqc2vw1xXtuI_r1xTNg       1      1     1  "Le Roy Pendu"
# -0uEqc2vw1xXtuI_r1xTNg       0      0     0  "Le Roy Pendu"
# -0uEqc2vw1xXtuI_r1xTNg       2      0     0  "Le Roy Pendu"
# -0uEqc2vw1xXtuI_r1xTNg       3      0     0  "Le Roy Pendu"
# -0uEqc2vw1xXtuI_r1xTNg       2      0     0  "Le Roy Pendu"
#
#                               neighborhood      address      city state  \
# business_id
# -0uEqc2vw1xXtuI_r1xTNg  Plateau-Mont-Royal  "804 Roy E"  Montréal    QC
# -0uEqc2vw1xXtuI_r1xTNg  Plateau-Mont-Royal  "804 Roy E"  Montréal    QC
# -0uEqc2vw1xXtuI_r1xTNg  Plateau-Mont-Royal  "804 Roy E"  Montréal    QC
# -0uEqc2vw1xXtuI_r1xTNg  Plateau-Mont-Royal  "804 Roy E"  Montréal    QC
# -0uEqc2vw1xXtuI_r1xTNg  Plateau-Mont-Royal  "804 Roy E"  Montréal    QC
#
#                        postal_code  latitude  longitude  review_count  \
# business_id
# -0uEqc2vw1xXtuI_r1xTNg     H2L 1E3  45.52099  -73.57096           6.0
# -0uEqc2vw1xXtuI_r1xTNg     H2L 1E3  45.52099  -73.57096           6.0
# -0uEqc2vw1xXtuI_r1xTNg     H2L 1E3  45.52099  -73.57096           6.0
# -0uEqc2vw1xXtuI_r1xTNg     H2L 1E3  45.52099  -73.57096           6.0
# -0uEqc2vw1xXtuI_r1xTNg     H2L 1E3  45.52099  -73.57096           6.0
#
#                         is_open  \
# business_id
# -0uEqc2vw1xXtuI_r1xTNg      0.0
# -0uEqc2vw1xXtuI_r1xTNg      0.0
# -0uEqc2vw1xXtuI_r1xTNg      0.0
# -0uEqc2vw1xXtuI_r1xTNg      0.0
# -0uEqc2vw1xXtuI_r1xTNg      0.0
#
#                                                                categories  \
# business_id
# -0uEqc2vw1xXtuI_r1xTNg  Restaurants;Tapas/Small Plates;Breakfast & Brunch
# -0uEqc2vw1xXtuI_r1xTNg  Restaurants;Tapas/Small Plates;Breakfast & Brunch
# -0uEqc2vw1xXtuI_r1xTNg  Restaurants;Tapas/Small Plates;Breakfast & Brunch
# -0uEqc2vw1xXtuI_r1xTNg  Restaurants;Tapas/Small Plates;Breakfast & Brunch
# -0uEqc2vw1xXtuI_r1xTNg  Restaurants;Tapas/Small Plates;Breakfast & Brunch
#
#                         avg_stars
# business_id
# -0uEqc2vw1xXtuI_r1xTNg        3.0
# -0uEqc2vw1xXtuI_r1xTNg        3.0
# -0uEqc2vw1xXtuI_r1xTNg        3.0
# -0uEqc2vw1xXtuI_r1xTNg        3.0
# -0uEqc2vw1xXtuI_r1xTNg        3.0

# %%
from langdetect import detect
from collections import Counter

# %%
lang = []

for text in food_reviews_qc["text"]:
    lang.append(detect(text))

# %%
Counter(lang)
# Out:
# Counter({'af': 6,
#          'ca': 13,
#          'cy': 1,
#          'de': 49,
#          'en': 96503,
#          'es': 69,
#          'et': 1,
#          'fi': 1,
#          'fr': 14558,
#          'hr': 1,
#          'hu': 1,
#          'id': 2,
#          'it': 26,
#          'ja': 9,
#          'ko': 6,
#          'lt': 1,
#          'nl': 8,
#          'no': 3,
#          'pt': 22,
#          'ro': 1,
#          'sk': 2,
#          'sv': 7,
#          'sw': 1,
#          'tl': 1,
#          'tr': 2,
#          'vi': 1,
#          'zh-cn': 25,
#          'zh-tw': 3})

# %%
reviews = food_reviews_qc["text"]

# %%
reviews
# Out:
# business_id
# -0uEqc2vw1xXtuI_r1xTNg    A small restaurant near the eastern end of Roy...
# -0uEqc2vw1xXtuI_r1xTNg    Went in May with a Groupon coupon and it was p...
# -0uEqc2vw1xXtuI_r1xTNg    Le Roy pendu, vive le Roy! Petit restaurant de...
# -0uEqc2vw1xXtuI_r1xTNg    I had brunch here the other day, it was great!...
# -0uEqc2vw1xXtuI_r1xTNg    Me and a friend ended up here for brunch after...
# -0uEqc2vw1xXtuI_r1xTNg    Went a Thursday night with a friend, was the l...
# -1CI4H3DLkI-NdWLbIae6g    Pas toujours au top niveau.  Mon dernier lunch...
# -1CI4H3DLkI-NdWLbIae6g    Vraiment meilleur que le st-hubert de sainte-j...
# -1CI4H3DLkI-NdWLbIae6g    If you're a fan of Swiss Chalet it's disappoin...
# -1CI4H3DLkI-NdWLbIae6g    Excellent qualité vs prix mais il ne font pas ...
# -1CI4H3DLkI-NdWLbIae6g    Overall good place to go grab a snack or meal ...
# -1xuC540Nycht_iWFeJ-dw    one of my favorite bbq chicken place in montre...
# -1xuC540Nycht_iWFeJ-dw    This place is good. I mean who doesn't love ch...
# -1xuC540Nycht_iWFeJ-dw    With a 1\/2 pound of chicken in piri sauce tha...
# -1xuC540Nycht_iWFeJ-dw    A Portuguese chicken staple that I love and fr...
# -1xuC540Nycht_iWFeJ-dw    Yum and a great deal!!  Finger licking good ch...
# -1xuC540Nycht_iWFeJ-dw    Meilleur poulet à Montréal. Les prix sont exce...
# -1xuC540Nycht_iWFeJ-dw    A Montreal staple, Romados serves up some damn...
# -1xuC540Nycht_iWFeJ-dw    If you go to Romados don't wait for a fancy pl...
# -1xuC540Nycht_iWFeJ-dw    Swiss Chalet, step aside.  Kenny Rogers chicke...
# -1xuC540Nycht_iWFeJ-dw    Some call chicken "the tuna of the turf." I do...
# -1xuC540Nycht_iWFeJ-dw    I was in vacation in Montreal, stayed at the P...
# -1xuC540Nycht_iWFeJ-dw    Rating: 4.25 \n\nHuge portions! I got the 1\/4...
# -1xuC540Nycht_iWFeJ-dw    Stopped here from the great reviews on here an...
# -1xuC540Nycht_iWFeJ-dw    I live in the US now and this is one of the pl...
# -1xuC540Nycht_iWFeJ-dw    If you are in the area and hungry, there is no...
# -1xuC540Nycht_iWFeJ-dw    Chicken was too salty.  Ask for the hot sace. ...
# -1xuC540Nycht_iWFeJ-dw    Really good food - some of the best chicken I'...
# -1xuC540Nycht_iWFeJ-dw    First and only time i've had portuguese chicke...
# -1xuC540Nycht_iWFeJ-dw    Superbe adresse pour les amateurs de poulet ! ...
#                                                 ...
# zzlZJVkEhOzR2tJOLHcF2A    We shared all three of their signature (tradit...
# zzlZJVkEhOzR2tJOLHcF2A    Hidden gem of a restaurant that you would defi...
# zzlZJVkEhOzR2tJOLHcF2A    Beef soup is good but the portion is really sm...
# zzlZJVkEhOzR2tJOLHcF2A    It is a very cosy place. decent food with good...
# zzlZJVkEhOzR2tJOLHcF2A    This restaurant really cares about their custo...
# zzlZJVkEhOzR2tJOLHcF2A    Price is fair, food is DELICIOUS! Where to sta...
# zzlZJVkEhOzR2tJOLHcF2A    I was really looking forward to visiting maiso...
# zzlZJVkEhOzR2tJOLHcF2A    I ordered fried Singapore style noodles, it wa...
# zzlZJVkEhOzR2tJOLHcF2A    Went here last night with a small group of Yel...
# zzlZJVkEhOzR2tJOLHcF2A    Little hidden Gem in Saint-Laurent.\n\nHad the...
# zzlZJVkEhOzR2tJOLHcF2A    Just finished having the most delicious bowl o...
# zzlZJVkEhOzR2tJOLHcF2A    I been here last Friday  the food really nice ...
# zzlZJVkEhOzR2tJOLHcF2A    First time visiting this Taiwanese style resta...
# zzlZJVkEhOzR2tJOLHcF2A    La soupe taiwanaise avec porc est médiocre, il...
# zzlZJVkEhOzR2tJOLHcF2A    An amazing hidden gem mom and pop kitchen. I h...
# zzlZJVkEhOzR2tJOLHcF2A    I go there once in a while to get their home m...
# zzlZJVkEhOzR2tJOLHcF2A    Very good Taiwan food, the beef noodle is the ...
# zzlZJVkEhOzR2tJOLHcF2A    Quick and courteous service. This is a small f...
# zzlZJVkEhOzR2tJOLHcF2A    Authentic homecooked food. Owner is very welco...
# zzlZJVkEhOzR2tJOLHcF2A    I visited Maison Mignon in June 2017 during a ...
# zzlZJVkEhOzR2tJOLHcF2A    We came here recommended by a friend to try ou...
# zzlZJVkEhOzR2tJOLHcF2A    Went as a Chinese family of 5 including a todd...
# zzlZJVkEhOzR2tJOLHcF2A    What a big disappointment!\n\nI was prepared t...
# zzlZJVkEhOzR2tJOLHcF2A    This is such a cozy asian restaurant, the owne...
# zzlZJVkEhOzR2tJOLHcF2A    That beef noodle soup is incredible, would be ...
# zzlZJVkEhOzR2tJOLHcF2A    We discovered this restaurant through Yelp a f...
# zzlZJVkEhOzR2tJOLHcF2A    Ever since I got back from Taiwan, I havent go...
# zzlZJVkEhOzR2tJOLHcF2A    This place is definitely a hidden gem. Yelp's ...
# zzlZJVkEhOzR2tJOLHcF2A    The chicken is awful!! It doesn't even feel li...
# zzlZJVkEhOzR2tJOLHcF2A    Friendly place and the beef noodle soup is fan...
# Name: text, Length: 111323, dtype: object
